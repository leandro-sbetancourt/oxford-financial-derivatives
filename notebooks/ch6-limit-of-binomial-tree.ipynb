# %%
import sys
sys.path.append('../')
import src.utils as utils
from importlib import reload
import numpy as np
import matplotlib.pyplot as plt
reload(utils)
import scipy.stats as stat

# %%
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (6, 4),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)
# %config InlineBackend.figure_format = "retina"
import warnings
warnings.filterwarnings("ignore")

import matplotlib
plt.rc('text', usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{amsmath,amsfonts}')

# %%
params = {
    'r' : 0.01,
    'p' : 0.5 ,
    'u' : 1.02,
    'd' : 0.99,
    'T' : 1,
    'S0' : 100,
    'Nt': 10,
}

BT = utils.binomial_tree(**params)

# %%
plt.plot(BT.timesteps, BT.simulate(nsims = 3), alpha = 0.5)
plt.show()

# %%
sigma = 0.2
Nt = 1000
T = 1.
mu = 0.3
r = 0.01
u = 1. + sigma * np.sqrt(T/Nt)
d = 1./u
p = 0.5 + (mu / (2.*sigma) - sigma/4)* np.sqrt(T/Nt)

params = {
    'r' : r,
    'p' : p,
    'u' : u,
    'd' : d,
    'T' : T,
    'S0' : 100,
    'Nt': Nt,
}

BT = utils.binomial_tree(**params)

# %%
plt.plot(BT.timesteps, BT.simulate(nsims = 100), alpha = 0.3)
plt.show()

# %%
GBM = utils.GeometricBrownianMotion(x0 = 100., mu = mu, sigma = sigma, T = T, Nt = Nt)

# %%
plt.plot(GBM.timesteps, GBM.simulate(nsims = 100), alpha = 0.3)
plt.show()
